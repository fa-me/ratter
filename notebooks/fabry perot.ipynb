# %%
from ratter import *

# %%
Ag = Material("Ag", refractive_index_value=0.050000+3.1309j)
air = Material("air", refractive_index_value=1)

# %%
import sympy as sp

# %%
d = sp.Symbol('d')

# %%
l1 = Layer("air", air, sp.oo)
l2 = Layer("M1", Ag, 200)
l3 = Layer("space", air, d)
l4 = Layer("M2", Ag, 200)
l5 = Layer("air", air, sp.oo)

stack = Layerstack([l1,l2,l3,l4,l5])

# %%
T = stack.transmittance_amplitude()*sp.conjugate(stack.transmittance_amplitude())

# %%
fn = as_function_of(T, [LAMBDA_VAC, d])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wl = np.linspace(500, 510, num=1000)

# %%
# %matplotlib inline

plt.figure()

for d_ in [1e4, 1.5e4, 2e4]:
    plt.plot(wl, np.real(fn(wl, d_)), label=str(d_))
    
plt.legend()
